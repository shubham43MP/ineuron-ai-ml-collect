# %%
import pandas as pd

# %%
ls
# Out:
# 15-jan-2022-exception-handling-and-logging.ipynb
# 19dec-python-program-discussion.ipynb
# 20-dec-python-program-discussion.ipynb
# 21-dec-python-program-discussion.ipynb
# 23-JAN-2022-OOPS.ipynb
# 23-dec-function.ipynb
# 26-FEB-2022-PANDAS.ipynb
# 29-JAN-2022-OOPS-ADVANCED.ipynb
# 30-JAN-2022-polymorphism-overload-override-static-custom-exceptions.ipynb
# 8-jan-python-functions-part-2.ipynb
# 9-jan-python-iterator-generator.ipynb
# __pycache__/
# basic-2-dec5.ipynb
# basic-3-dec18-tuples-set-dict.ipynb
# google.txt
# mydict.py
# pythonbasic-1-dec-4.ipynb
# test.IPYNB
# test.log
# test.txt
# test1.text
# test1classdec4.ipynb

# %%
pd.read

# %%
ls
# Out:
# 15-jan-2022-exception-handling-and-logging.ipynb
# 19dec-python-program-discussion.ipynb
# 20-dec-python-program-discussion.ipynb
# 21-dec-python-program-discussion.ipynb
# 23-JAN-2022-OOPS.ipynb
# 23-dec-function.ipynb
# 26-FEB-2022-PANDAS.ipynb
# 29-JAN-2022-OOPS-ADVANCED.ipynb
# 30-JAN-2022-polymorphism-overload-override-static-custom-exceptions.ipynb
# 8-jan-python-functions-part-2.ipynb
# 9-jan-python-iterator-generator.ipynb
# Sample.csv
# __pycache__/
# basic-2-dec5.ipynb
# basic-3-dec18-tuples-set-dict.ipynb
# google.txt
# mydict.py
# pythonbasic-1-dec-4.ipynb
# test.IPYNB
# test.log
# test.txt
# test1.text
# test1classdec4.ipynb

# %%
pd.read_csv('Sample.csv')
# Out:
#         name        emailid address     pin surname
# 0  Sudhanshu  abc@gmail.com     RTM  457001   Kumar
# 1    Shubham  xyz@gmail.com    INDB  452001   DIXIT
# 2      Vayam  hjk@GMAIL.COM     UJN  454001    JAIN

# %%
df = pd.read_csv('/Users/shudixit/data-ml/sample-csv/taxonomy.csv')

# %%
# Pandas work with a concept called as Data frame like SQL uses tables and stuff

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df ## See this is not a correct thing as frst row is not a column name
# Out:
#            101                     Emergency Unnamed: 2            Unnamed: 3
# 0       101-01             Disaster Response        101             Emergency
# 1       101-02                Emergency Cash        101             Emergency
# 2    101-02-01             Help Pay for Food     101-02        Emergency Cash
# 3    101-02-02       Help Pay for Healthcare     101-02        Emergency Cash
# 4    101-02-03          Help Pay for Housing     101-02        Emergency Cash
# ..         ...                           ...        ...                   ...
# 284  111-01-07              Workplace Rights     111-01  Advocacy & Legal Aid
# 285     111-02                     Mediation        111                 Legal
# 286     111-03                        Notary        111                 Legal
# 287     111-04                Representation        111                 Legal
# 288     111-05  Translation & Interpretation        111                 Legal
#
# [289 rows x 4 columns]

# %%
df1 = pd.read_csv('taxonomy.csv', header=None) # No headers in the DataFrame
df1
# Out:
#              0                             1       2                     3
# 0          101                     Emergency     NaN                   NaN
# 1       101-01             Disaster Response     101             Emergency
# 2       101-02                Emergency Cash     101             Emergency
# 3    101-02-01             Help Pay for Food  101-02        Emergency Cash
# 4    101-02-02       Help Pay for Healthcare  101-02        Emergency Cash
# ..         ...                           ...     ...                   ...
# 285  111-01-07              Workplace Rights  111-01  Advocacy & Legal Aid
# 286     111-02                     Mediation     111                 Legal
# 287     111-03                        Notary     111                 Legal
# 288     111-04                Representation     111                 Legal
# 289     111-05  Translation & Interpretation     111                 Legal
#
# [290 rows x 4 columns]

# %%
df2 = pd.read_csv('taxonomy.csv', names=['a', 'b', 'c', 'd']) # Custom header names, more or less columns will adjust accordingly
df2
# Out:
#              a                             b       c                     d
# 0          101                     Emergency     NaN                   NaN
# 1       101-01             Disaster Response     101             Emergency
# 2       101-02                Emergency Cash     101             Emergency
# 3    101-02-01             Help Pay for Food  101-02        Emergency Cash
# 4    101-02-02       Help Pay for Healthcare  101-02        Emergency Cash
# ..         ...                           ...     ...                   ...
# 285  111-01-07              Workplace Rights  111-01  Advocacy & Legal Aid
# 286     111-02                     Mediation     111                 Legal
# 287     111-03                        Notary     111                 Legal
# 288     111-04                Representation     111                 Legal
# 289     111-05  Translation & Interpretation     111                 Legal
#
# [290 rows x 4 columns]

# %%
# Delimiter/Seprator can be anything other than comma if the file actually have it. Default is comma
df2 = pd.read_csv('Sample.csv', sep=',') 
df2
# Out:
#         name        emailid address     pin surname
# 0  Sudhanshu  abc@gmail.com     RTM  457001   Kumar
# 1    Shubham  xyz@gmail.com    INDB  452001   DIXIT
# 2      Vayam  hjk@GMAIL.COM     UJN  454001    JAIN

# %%
df2 = pd.read_csv('Sample.csv', skiprows=[1,3])

# %%
df2
# Out:
#       name        emailid address     pin surname
# 0  Shubham  xyz@gmail.com    INDB  452001   DIXIT

# %%
df = pd.read_csv('services.csv')

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.dtypes
# Out:
# id                           int64
# location_id                  int64
# program_id                 float64
# accepted_payments           object
# alternate_name              object
# application_process         object
# audience                    object
# description                 object
# eligibility                 object
# email                       object
# fees                        object
# funding_sources             object
# interpretation_services     object
# keywords                    object
# languages                   object
# name                        object
# required_documents          object
# service_areas               object
# status                      object
# wait_time                   object
# website                     object
# taxonomy_ids                object
# dtype: object

# %%
df
# Out:
#     id  location_id  program_id         accepted_payments  \
# 0    1            1         NaN                       NaN
# 1    2            2         NaN                       NaN
# 2    3            3         NaN                       NaN
# 3    4            4         NaN                       NaN
# 4    5            5         NaN                       NaN
# 5    6            6         NaN                       NaN
# 6    7            7         NaN                       NaN
# 7    8            8         NaN                       NaN
# 8    9            9         NaN                       NaN
# 9   10           10         NaN                       NaN
# 10  11           11         NaN                       NaN
# 11  12           12         NaN                       NaN
# 12  13           13         NaN                       NaN
# 13  14           14         NaN                       NaN
# 14  15           15         NaN                       NaN
# ...

# %%
df.head(3) # just 5 records which gives the type of data from top
# Out:
#    id  location_id  program_id accepted_payments alternate_name  \
# 0   1            1         NaN               NaN            NaN
# 1   2            2         NaN               NaN            NaN
# 2   3            3         NaN               NaN            NaN
#
#                            application_process  \
# 0                   Walk in or apply by phone.
# 1           Apply by phone for an appointment.
# 2  Phone for information (403-4300 Ext. 4322).
#
#                                             audience  \
# 0  Older adults age 55 or over, ethnic minorities...
# 1       Residents of San Mateo County age 55 or over
# 2  Older adults age 55 or over who can benefit fr...
#
#                                          description  \
# 0  A walk-in center for older adults that provide...
# 1  Provides training and job placement to eligibl...
# 2  Offers supportive counseling services to San M...
#
#                                          eligibility email  ...  \
# ...

# %%
df.tail(5) # just 5 records which gives the type of data from bottom
# Out:
#     id  location_id  program_id         accepted_payments  \
# 18  19           19         NaN                       NaN
# 19  20           20         NaN                       NaN
# 20  21           21         NaN                       NaN
# 21  22           22         NaN  Cash, Check, Credit Card
# 22  23           22         NaN                       NaN
#
#            alternate_name                             application_process  \
# 18                    NaN  Call for screening appointment (650-347-3648).
# 19                    NaN                                        Walk in.
# 20                    NaN                 By phone during business hours.
# 21  Fotos para pasaportes               Walk in or apply by phone or mail
# 22                    NaN               Walk in or apply by phone or mail
#
#                                              audience  \
# 18                                                NaN
# 19                                                NaN
# ...

# %%
df.columns
# Out:
# Index(['id', 'location_id', 'program_id', 'accepted_payments',
#        'alternate_name', 'application_process', 'audience', 'description',
#        'eligibility', 'email', 'fees', 'funding_sources',
#        'interpretation_services', 'keywords', 'languages', 'name',
#        'required_documents', 'service_areas', 'status', 'wait_time', 'website',
#        'taxonomy_ids'],
#       dtype='object')

# %%
df.dtypes
# Out:
# id                           int64
# location_id                  int64
# program_id                 float64
# accepted_payments           object
# alternate_name              object
# application_process         object
# audience                    object
# description                 object
# eligibility                 object
# email                       object
# fees                        object
# funding_sources             object
# interpretation_services     object
# keywords                    object
# languages                   object
# name                        object
# required_documents          object
# service_areas               object
# status                      object
# wait_time                   object
# website                     object
# taxonomy_ids                object
# dtype: object

# %%
df['website'] # Particular column access
# Out:
# 0                        NaN
# 1                        NaN
# 2                        NaN
# 3                        NaN
# 4                        NaN
# 5                        NaN
# 6                        NaN
# 7                        NaN
# 8                        NaN
# 9                        NaN
# 10                       NaN
# 11                       NaN
# 12                       NaN
# 13                       NaN
# 14                       NaN
# 15                       NaN
# 16                       NaN
# 17                       NaN
# 18                       NaN
# 19                       NaN
# 20                       NaN
# 21    http://www.example.com
# 22    http://www.example.com
# Name: website, dtype: object

# %%
df['website']
# Out:
# 0                        NaN
# 1                        NaN
# 2                        NaN
# 3                        NaN
# 4                        NaN
# 5                        NaN
# 6                        NaN
# 7                        NaN
# 8                        NaN
# 9                        NaN
# 10                       NaN
# 11                       NaN
# 12                       NaN
# 13                       NaN
# 14                       NaN
# 15                       NaN
# 16                       NaN
# 17                       NaN
# 18                       NaN
# 19                       NaN
# 20                       NaN
# 21    http://www.example.com
# 22    http://www.example.com
# Name: website, dtype: object

# %%
a = df['name'] # COLUMNS ARE BY DEFAULT A SERIES
type(a)
# Out:
# pandas.core.series.Series

# %%
# DATAFRAMES ARE A COMBINATION OF SERIES

# %%
df[['name']]
# Out:
#                                     name
# 0        Fair Oaks Adult Activity Center
# 1       Second Career Employment Program
# 2                 Senior Peer Counseling
# 3               Family Visitation Center
# 4      Economic Self-Sufficiency Program
# 5   Little House Recreational Activities
# 6       Rosener House Adult Day Services
# 7         Meals on Wheels - South County
# 8                       Fair Oaks Branch
# 9                           Main Library
# 10                       Schaberg Branch
# 11                          Project Read
# 12                 Redwood Shores Branch
# 13                    Redwood City Corps
# 14           Adult Rehabilitation Center
# 15                       Sunnyvale Corps
# 16     South San Francisco Citadel Corps
# 17                         Project Smile
# 18         San Mateo Free Medical Clinic
# 19             Service with blank fields
# 20       Service for Admin Test Location
# 21                       Passport Photos
# ...

# %%
type(df[['name', 'email']])
# Out:
# pandas.core.frame.DataFrame

# %%
df[['name', 'email']] # Multiple column access
# Out:
#                                     name                  email
# 0        Fair Oaks Adult Activity Center                    NaN
# 1       Second Career Employment Program                    NaN
# 2                 Senior Peer Counseling                    NaN
# 3               Family Visitation Center                    NaN
# 4      Economic Self-Sufficiency Program                    NaN
# 5   Little House Recreational Activities                    NaN
# 6       Rosener House Adult Day Services                    NaN
# 7         Meals on Wheels - South County                    NaN
# 8                       Fair Oaks Branch                    NaN
# 9                           Main Library                    NaN
# 10                       Schaberg Branch                    NaN
# 11                          Project Read                    NaN
# 12                 Redwood Shores Branch                    NaN
# 13                    Redwood City Corps                    NaN
# ...

# %%
# SUMMARY
# Pandas work with a concept called as Data frame like SQL uses tables and stuff
# See this is not a correct thing as frst row is not a column name
# Delimiter/Seprator can be anything other than comma if the file actually have it. Default is comma
# COLUMNS ARE BY DEFAULT A SERIES
# DATAFRAMES ARE A COMBINATION OF SERIES
# df['website'] # Particular column access
# df.tail(5) # just 5 records which gives the type of data from bottom
# df.head(3) # just 5 records which gives the type of data from top
