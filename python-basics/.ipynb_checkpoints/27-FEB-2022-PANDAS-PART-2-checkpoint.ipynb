# %%
import pandas as pd

# %%
df = pd.read_html('https://www.basketball-reference.com/leagues/NBA_2015_totals.html')

# %%
type(df)
# Out:
# list

# %%
len(df)
# Out:
# 1

# %%
df[0] # This is the comlete structural format
# Out:
#       Rk          Player Pos Age   Tm   G  GS    MP   FG  FGA  ...   FT%  ORB  \
# 0      1      Quincy Acy  PF  24  NYK  68  22  1287  152  331  ...  .784   79
# 1      2    Jordan Adams  SG  20  MEM  30   0   248   35   86  ...  .609    9
# 2      3    Steven Adams   C  21  OKC  70  67  1771  217  399  ...  .502  199
# 3      4     Jeff Adrien  PF  28  MIN  17   0   215   19   44  ...  .579   23
# 4      5   Arron Afflalo  SG  29  TOT  78  72  2502  375  884  ...  .843   27
# ..   ...             ...  ..  ..  ...  ..  ..   ...  ...  ...  ...   ...  ...
# 670  490  Thaddeus Young  PF  26  TOT  76  68  2434  451  968  ...  .655  127
# 671  490  Thaddeus Young  PF  26  MIN  48  48  1605  289  641  ...  .682   75
# 672  490  Thaddeus Young  PF  26  BRK  28  20   829  162  327  ...  .606   52
# 673  491     Cody Zeller   C  22  CHO  62  45  1487  172  373  ...  .774   97
# 674  492    Tyler Zeller   C  25  BOS  82  59  1731  340  619  ...  .823  146
#
# ...

# %%
type(df[0])
# Out:
# pandas.core.frame.DataFrame

# %%
df1 = df[0]

# %%
df1.columns
# Out:
# Index(['Rk', 'Player', 'Pos', 'Age', 'Tm', 'G', 'GS', 'MP', 'FG', 'FGA', 'FG%',
#        '3P', '3PA', '3P%', '2P', '2PA', '2P%', 'eFG%', 'FT', 'FTA', 'FT%',
#        'ORB', 'DRB', 'TRB', 'AST', 'STL', 'BLK', 'TOV', 'PF', 'PTS'],
#       dtype='object')

# %% [markdown]
# df1.head()

# %%
df1.tail()
# Out:
#       Rk          Player Pos Age   Tm   G  GS    MP   FG  FGA  ...   FT%  ORB  \
# 670  490  Thaddeus Young  PF  26  TOT  76  68  2434  451  968  ...  .655  127
# 671  490  Thaddeus Young  PF  26  MIN  48  48  1605  289  641  ...  .682   75
# 672  490  Thaddeus Young  PF  26  BRK  28  20   829  162  327  ...  .606   52
# 673  491     Cody Zeller   C  22  CHO  62  45  1487  172  373  ...  .774   97
# 674  492    Tyler Zeller   C  25  BOS  82  59  1731  340  619  ...  .823  146
#
#      DRB  TRB  AST  STL BLK  TOV   PF   PTS
# 670  284  411  173  124  25  117  171  1071
# 671  170  245  135   86  17   75  115   685
# 672  114  166   38   38   8   42   56   386
# 673  265  362  100   34  49   62  156   472
# 674  319  465  113   18  52   76  205   833
#
# [5 rows x 30 columns]

# %%
df1.dtypes
# Out:
# Rk        object
# Player    object
# Pos       object
# Age       object
# Tm        object
# G         object
# GS        object
# MP        object
# FG        object
# FGA       object
# FG%       object
# 3P        object
# 3PA       object
# 3P%       object
# 2P        object
# 2PA       object
# 2P%       object
# eFG%      object
# FT        object
# FTA       object
# FT%       object
# ORB       object
# DRB       object
# TRB       object
# AST       object
# STL       object
# BLK       object
# TOV       object
# PF        object
# PTS       object
# dtype: object

# %%
df1[['Age', 'GS']]
# Out:
#     Age  GS
# 0    24  22
# 1    20   0
# 2    21  67
# 3    28   0
# 4    29  72
# ..   ..  ..
# 670  26  68
# 671  26  48
# 672  26  20
# 673  22  45
# 674  25  59
#
# [675 rows x 2 columns]

# %%
df1.to_csv('ABC.csv')

# %%
d = """
{
 "name": "Shubham Dixit",
 "emailid": "abc@gmail.com",
 "tech": ["ML","DL", "REACT"],
 "platform": ["ineuron", "kidsneuron", "ABC"]
}
"""

# %%
import json

# %%
result = json.loads(d)

# %%
result
# Out:
# {'name': 'Shubham Dixit',
#  'emailid': 'abc@gmail.com',
#  'tech': ['ML', 'DL', 'REACT'],
#  'platform': ['ineuron', 'kidsneuron', 'ABC']}

# %%
type(result)
# Out:
# dict

# %%
pd.DataFrame(result)
# Out:
#             name        emailid   tech    platform
# 0  Shubham Dixit  abc@gmail.com     ML     ineuron
# 1  Shubham Dixit  abc@gmail.com     DL  kidsneuron
# 2  Shubham Dixit  abc@gmail.com  REACT         ABC

# %%
url = 'https://api.github.com/repos/pandas-dev/pandas/issues'
pd.read_json(url)
# Out:
#                                                   url  \
# 0   https://api.github.com/repos/pandas-dev/pandas...
# 1   https://api.github.com/repos/pandas-dev/pandas...
# 2   https://api.github.com/repos/pandas-dev/pandas...
# 3   https://api.github.com/repos/pandas-dev/pandas...
# 4   https://api.github.com/repos/pandas-dev/pandas...
# 5   https://api.github.com/repos/pandas-dev/pandas...
# 6   https://api.github.com/repos/pandas-dev/pandas...
# 7   https://api.github.com/repos/pandas-dev/pandas...
# 8   https://api.github.com/repos/pandas-dev/pandas...
# 9   https://api.github.com/repos/pandas-dev/pandas...
# 10  https://api.github.com/repos/pandas-dev/pandas...
# 11  https://api.github.com/repos/pandas-dev/pandas...
# 12  https://api.github.com/repos/pandas-dev/pandas...
# 13  https://api.github.com/repos/pandas-dev/pandas...
# 14  https://api.github.com/repos/pandas-dev/pandas...
# 15  https://api.github.com/repos/pandas-dev/pandas...
# ...

# %%
import requests
url = 'https://api.github.com/repos/pandas-dev/pandas/issues'

# %%
data = requests.get(url)

# %%
data
# Out:
# <Response [200]>

# %%
data1 = data.json()
data1
# Out:
# [{'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46793',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46793/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46793/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46793/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/issues/46793',
#   'id': 1206370745,
#   'node_id': 'I_kwDOAA0YD85H58G5',
#   'number': 46793,
#   'title': 'WEB: Use mambaforge for the getting started installation instructions?',
#   'user': {'login': 'datapythonista',
#    'id': 10058240,
#    'node_id': 'MDQ6VXNlcjEwMDU4MjQw',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/10058240?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/datapythonista',
#    'html_url': 'https://github.com/datapythonista',
# ...

# %%
len(data1)
# Out:
# 30

# %%
for i in range(len(data1)):
    print((data1[i]['user']['id']))
# Out:
# 10058240
# 19342156
# 21693509
# 68053396
# 56479219
# 6618166
# 68446210
# 59946643
# 20627856
# 77794567
# 77794567
# 13159005
# 10647082
# 18585219
# 34522496
# 4476168
# 11664259
# 15113894
# 31669
# 18078278
# 5351947
# 23336875
# 15113894
# 18585219
# 3236794
# 5758789
# 10820686
# 3211163
# 3211163
# 90400333

# %%
data1
# Out:
# [{'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46793',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46793/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46793/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46793/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/issues/46793',
#   'id': 1206370745,
#   'node_id': 'I_kwDOAA0YD85H58G5',
#   'number': 46793,
#   'title': 'WEB: Use mambaforge for the getting started installation instructions?',
#   'user': {'login': 'datapythonista',
#    'id': 10058240,
#    'node_id': 'MDQ6VXNlcjEwMDU4MjQw',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/10058240?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/datapythonista',
#    'html_url': 'https://github.com/datapythonista',
# ...

# %%
df2 = pd.DataFrame(data1, columns=['id', 'url', 'repository_url', 'labels_url', 'user'])

# %%
df2.to_csv('gh-response.csv')

# %%
df2
# Out:
#             id                                                url  \
# 0   1206370745  https://api.github.com/repos/pandas-dev/pandas...
# 1   1206301209  https://api.github.com/repos/pandas-dev/pandas...
# 2   1206170540  https://api.github.com/repos/pandas-dev/pandas...
# 3   1206164359  https://api.github.com/repos/pandas-dev/pandas...
# 4   1206141718  https://api.github.com/repos/pandas-dev/pandas...
# 5   1205872267  https://api.github.com/repos/pandas-dev/pandas...
# 6   1205849324  https://api.github.com/repos/pandas-dev/pandas...
# 7   1205765682  https://api.github.com/repos/pandas-dev/pandas...
# 8   1205740295  https://api.github.com/repos/pandas-dev/pandas...
# 9   1204923030  https://api.github.com/repos/pandas-dev/pandas...
# 10  1204912401  https://api.github.com/repos/pandas-dev/pandas...
# 11  1204378879  https://api.github.com/repos/pandas-dev/pandas...
# 12  1204039393  https://api.github.com/repos/pandas-dev/pandas...
# ...

# %%
# userDF = pd.DataFrame(df2['user'])
# userDF
df2['user'].values
pd.DataFrame(df2['user'].values)
# Out:
#                                                     0
# 0   {'login': 'datapythonista', 'id': 10058240, 'n...
# 1   {'login': 'lorentzbao', 'id': 19342156, 'node_...
# 2   {'login': 'ehariri', 'id': 21693509, 'node_id'...
# 3   {'login': 'mosc9575', 'id': 68053396, 'node_id...
# 4   {'login': 'shyamsantoki', 'id': 56479219, 'nod...
# 5   {'login': 'twoertwein', 'id': 6618166, 'node_i...
# 6   {'login': 'ben-feldstein', 'id': 68446210, 'no...
# 7   {'login': 'vruthik', 'id': 59946643, 'node_id'...
# 8   {'login': 'charlesbluca', 'id': 20627856, 'nod...
# 9   {'login': 'andjhall', 'id': 77794567, 'node_id...
# 10  {'login': 'andjhall', 'id': 77794567, 'node_id...
# 11  {'login': 'simonjayhawkins', 'id': 13159005, '...
# 12  {'login': 'mroeschke', 'id': 10647082, 'node_i...
# 13  {'login': 'joseortiz3', 'id': 18585219, 'node_...
# 14  {'login': 'ma3da', 'id': 34522496, 'node_id': ...
# 15  {'login': 'kwhkim', 'id': 4476168, 'node_id': ...
# ...

# %%
# Summary
# While fetching data from HTML, all the data frames in tabular format are fetched as a list
# df.to_csv('ABC.csv')  --> This will save data into CSV
# data1[0]['user']['id'] ==> Way to access a JSON
